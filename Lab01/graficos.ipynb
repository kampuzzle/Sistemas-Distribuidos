# %%
import pandas as pd 
import seaborn as sns
data = pd.read_csv('data/results.csv')
data.head()
# Out:
#    size  process_num      time
# 0    14            1  0.009638
# 1    14            2  0.008003
# 2    14            4  0.014234
# 3    14            6  0.021047
# 4    14            8  0.026769

# %%
#Plot the data seaborn
process_list = [1,2,4,6,8,10,12,14,16]
for size in data['size'].unique():
    data_size = data[data['size'] == size]
    sns.lineplot(x='process_num', y='time', data=data_size, label=f"Vector size: {size}")

# %%
#plt oone plot for each size 
import matplotlib.pyplot as plt
process_list = [1,2,4,6,8,10,12,14,16]
for size in data['size'].unique():
    data_size = data[data['size'] == size]
    plt.plot('process_num', 'time', data=data_size, label=f"Vector size: {size}")
    #legeds: y is time and x is process_num
    plt.xlabel('process_num')
    plt.ylabel('time')
    plt.legend()
    plt.savefig(f"data/size_{size}.png")
    plt.show()
